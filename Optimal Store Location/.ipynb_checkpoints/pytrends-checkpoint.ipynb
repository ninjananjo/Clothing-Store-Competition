# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading https://files.pythonhosted.org/packages/c7/ca/bf9ed973416290270c9aea8f8b3cf7e75a2280918838a4bea4067019ef11/pytrends-4.6.0-py3-none-any.whl
# Requirement already satisfied: pandas in c:\users\james\anaconda3\lib\site-packages (from pytrends) (0.24.2)
# Requirement already satisfied: requests in c:\users\james\anaconda3\lib\site-packages (from pytrends) (2.22.0)
# Requirement already satisfied: lxml in c:\users\james\anaconda3\lib\site-packages (from pytrends) (4.3.2)
# Requirement already satisfied: pytz>=2011k in c:\users\james\anaconda3\lib\site-packages (from pandas->pytrends) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\james\anaconda3\lib\site-packages (from pandas->pytrends) (2.8.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\james\anaconda3\lib\site-packages (from pandas->pytrends) (1.16.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\james\anaconda3\lib\site-packages (from requests->pytrends) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\james\anaconda3\lib\site-packages (from requests->pytrends) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\james\anaconda3\lib\site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\james\anaconda3\lib\site-packages (from requests->pytrends) (2.7)
# Requirement already satisfied: six>=1.5 in c:\users\james\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas->pytrends) (1.12.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.6.0

# %%
from pytrends.request import TrendReq
import pandas as pd
import requests
import lxml

# %%
pytrend = TrendReq()

kw_list = ["Fashion"]
pytrend.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='GB', gprop='')

# %%
interest_by_region_df = pytrend.interest_by_region(resolution='CITY', inc_low_vol=True)
print(interest_by_region_df.head())
# Out:
#                   Fashion
# geoName
# England               100
# Northern Ireland       91
# Scotland               92
# Wales                  88
