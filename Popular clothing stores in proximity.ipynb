# %%
# !pip install --upgrade git+https://github.com/m-wrzr/populartimes
# !pip install pandas

import numpy as np
import pandas as pd
import populartimes # https://github.com/m-wrzr/populartimes
import matplotlib.pyplot as plt # plotting library
# %matplotlib inline
# Out:
# ...
#   Cloning https://github.com/m-wrzr/populartimes to /tmp/pip-req-build-ubm48tu4
#   Running command git clone -q https://github.com/m-wrzr/populartimes /tmp/pip-req-build-ubm48tu4
# ...
#      |████████████████████████████████| 102kB 3.3MB/s ta 0:00:011
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-20sv1_kv/wheels/75/ae/aa/56b796466ed114d29102c9f74ec35c9a41b53c69ac5215d58a
# ...
#   Stored in directory: /home/jovyan/.cache/pip/wheels/99/45/d1/14954797e2a976083182c2e7da9b4e924509e59b6e5c661061
# Successfully built populartimes geographiclib
# ...
#      |████████████████████████████████| 10.1MB 3.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 512kB 9.8MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.3MB 191kB/s  eta 0:00:01
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c59867e5211d> in <module>
#       5 import pandas as pd
# ...

# %%
#import store location data
df_storelocations = pd.read_csv("https://raw.githubusercontent.com/ninjananjo/Clothing-Store-Competition/master/StoreLocations.csv", encoding = 'ISO-8859-1')
df_storelocations = df[['TOWN','NAME','ID','COUNTRY','Address1','Postcode','Host','PNO','NSF']]
df_storelocations = df_storelocations[(df_storelocations['ID']=='TS0001')]
df_storelocations
# Out:
#                        TOWN           NAME      ID COUNTRY           Address1  \
# 189  LONDON (OXFORD CIRCUS)  OXFORD CIRCUS  TS0001     ENG  214 Oxford Street
#
#     Postcode    Host   PNO    NSF
# 189  W1W 8LG  TS0001  8512  69207

# %%
df_storelocations = pd.read_csv('StoreLocations_LatLng.csv')
df_storelocations = df_storelocations[(df_storelocations['ID']=='TS0001')]
df_storelocations
