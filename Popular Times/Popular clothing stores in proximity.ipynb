# %%
# !pip install --upgrade git+https://github.com/m-wrzr/populartimes
# !pip install pandas

import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import populartimes # https://github.com/m-wrzr/populartimes
# Out:
# ...
#   Cloning https://github.com/m-wrzr/populartimes to c:\users\james\appdata\local\temp\pip-req-build-hogy9wnl
# ...
#   Stored in directory: C:\Users\james\AppData\Local\Temp\pip-ephem-wheel-cache-f7oiar1t\wheels\75\ae\aa\56b796466ed114d29102c9f74ec35c9a41b53c69ac5215d58a
# Successfully built populartimes
# ...
#   Found existing installation: populartimes 2.0
#     Uninstalling populartimes-2.0:
#       Successfully uninstalled populartimes-2.0
# ...

# %%
df_storelocations = pd.read_csv("https://raw.githubusercontent.com/ninjananjo/Clothing-Store-Competition/master/JD%20Sports%20Proximity/StoreLocations_LatLng.csv", encoding = 'ISO-8859-1')
df_storelocations = df_storelocations[(df_storelocations['Host']=='TS0001')]
df_storelocations
# Out:
#    Unnamed: 0    Host                    TOWN           NAME COUNTRY  \
# 7           7  TS0001  LONDON (OXFORD CIRCUS)  OXFORD CIRCUS     ENG
#
#             Address1 Postcode   PNO    NSF     Branch IDs   Latitude  \
# 7  214 Oxford Street  W1W 8LG  8512  69207  TM7329,TS0001  51.515534
#
#    Longitude
# 7  -0.141352

# %%
fields='place_id,name,formatted_address,geometry,permanently_closed,plus_code'
api_key='AIzaSyBTqRFNpFXp2r8o0lk6tbGIU92_35caKSU'
types = ['clothing_store'] #https://developers.google.com/places/supported_types
bound_upper = (51.516,-0.142)
bound_lower = (51.514,-0.140)

# %% [markdown]
# populartimes.get(api_key, types, bound_lower, bound_upper, n_threads (opt), radius (opt), all_places (opt))
#
# api_key str; api key from google places web service; e.g. "your-api-key"
# types [str]; placetypes; see https://developers.google.com/places/supported_types; e.g. ["bar"]
# p1 (float, float); lat/lng of point delimiting the search area; e.g. (48.132986, 11.566126)
# p2 (float, float); lat/lng of point delimiting the search area; e.g. (48.142199, 11.580047)
# n_threads (opt) int; number of threads used; e.g. 20
# radius (opt) int; meters; up to 50,000 for radar search; e.g. 180; this has can be adapted for very dense areas
# all_places (opt) bool; include/exclude places without populartimes

# %%
populartimes_json = populartimes.get(api_key, types, bound_lower, bound_upper, radius=100, all_places=False)

# %%
df_populartimes = json_normalize(populartimes_json)
df_populartimes
# Out:
#                           address  coordinates.lat  coordinates.lng  \
# 0   221-223 Oxford Street, London        51.515315        -0.140434
# 1       200 Oxford Street, London        51.515608        -0.140587
# 2       240 Regent Street, London        51.514259        -0.141341
# 3       214 Oxford Street, London        51.515514        -0.141265
# 4       214 Oxford Street, London        51.515664        -0.141608
# 5   225-235 Oxford Street, London        51.515306        -0.140471
# 6       236 Oxford Street, London        51.515488        -0.141824
# 7   223-235 Oxford Street, London        51.515278        -0.140818
# 8   266-270 Regent Street, London        51.515128        -0.141646
# 9       260 Regent Street, London        51.514955        -0.141628
# 10  256-258 Regent Street, London        51.514828        -0.141622
# 11      244 Regent Street, London        51.514327        -0.141407
#
#     current_popularity                           id  \
# ...
